# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Step1 - Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Step2 - Get the nearest city using the citypy module. Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 736

# %%
# Step3 - Perform and API call with OpenWeatherMap
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | vaini
# Processing Record 2 of the Set 1 | coihaique
# Processing Record 3 of the Set 1 | albany
# Processing Record 4 of the Set 1 | rikitea
# Processing Record 5 of the Set 1 | kapaa
# Processing Record 6 of the Set 1 | lagoa
# Processing Record 7 of the Set 1 | nikolskoye
# Processing Record 8 of the Set 1 | magdagachi
# Processing Record 9 of the Set 1 | ushuaia
# Processing Record 10 of the Set 1 | gobabis
# Processing Record 11 of the Set 1 | constitucion
# Processing Record 12 of the Set 1 | cayenne
# Processing Record 13 of the Set 1 | torbay
# Processing Record 14 of the Set 1 | port alfred
# Processing Record 15 of the Set 1 | yellowknife
# Processing Record 16 of the Set 1 | aripuana
# Processing Record 17 of the Set 1 | qaanaaq
# Processing Record 18 of the Set 1 | rongcheng
# Processing Record 19 of the Set 1 | hobart
# Processing Record 20 of the Set 1 | saldanha
# Processing Record 21 of the Set 1 | busselton
# Processing Record 22 of the Set 1 | arraial do cabo
# Processing Record 23 of the Set 1 | barcelos
# Processing Record 24 of the Set 1 | kodiak
# Processing Record 25 of the Set 1 | tumannyy
# Processing Record 26 of the Set 1 | sentyabrskiy
# Processing Record 27 of the Set 1 | fortuna
# Processing Record 28 of the Set 1 | ancud
# Processing Record 29 of the Set 1 | pitanga
# Processing Record 30 of the Set 1 | dingle
# Processing Record 31 of the Set 1 | kavieng
# Processing Record 32 of the Set 1 | punta arenas
# Processing Record 33 of the Set 1 | cherskiy
# Processing Record 34 of the Set 1 | half moon bay
# Processing Record 35 of the Set 1 | bogorodskoye
# Processing Record 36 of the Set 1 | dzhebariki-khaya
# Processing Record 37 of the Set 1 | salalah
# Processing Record 38 of the Set 1 | upernavik
# Processing Record 39 of the Set 1 | yelkhovka
# Processing Record 40 of the Set 1 | clyde river
# Processing Record 41 of the Set 1 | karamay
# Processing Record 42 of the Set 1 | hithadhoo
# Processing Record 43 of the Set 1 | belushya guba
# Processing Record 44 of the Set 1 | warrnambool
# Processing Record 45 of the Set 1 | luderitz
# Processing Record 46 of the Set 1 | cape town
# Processing Record 47 of the Set 1 | pochutla
# Processing Record 48 of the Set 1 | hermanus
# Processing Record 49 of the Set 1 | port-gentil
# Processing Record 50 of the Set 1 | georgetown
# Processing Record 1 of the Set 2 | attawapiskat
# Processing Record 2 of the Set 2 | shenjiamen
# Processing Record 3 of the Set 2 | puerto ayora
# Processing Record 4 of the Set 2 | zhuhai
# Processing Record 5 of the Set 2 | lalmohan
# Processing Record 6 of the Set 2 | pontianak
# Processing Record 7 of the Set 2 | sechura
# Processing Record 8 of the Set 2 | kokopo
# Processing Record 9 of the Set 2 | bredasdorp
# Processing Record 10 of the Set 2 | podor
# Processing Record 11 of the Set 2 | carnarvon
# Processing Record 12 of the Set 2 | jamestown
# Processing Record 13 of the Set 2 | atuona
# Processing Record 14 of the Set 2 | astara
# Processing Record 15 of the Set 2 | makakilo city
# Processing Record 16 of the Set 2 | buraydah
# Processing Record 17 of the Set 2 | poso
# Processing Record 18 of the Set 2 | mataura
# Processing Record 19 of the Set 2 | jumla
# Processing Record 20 of the Set 2 | nokaneng
# Processing Record 21 of the Set 2 | krutinka
# Processing Record 22 of the Set 2 | atambua
# Processing Record 23 of the Set 2 | jabiru
# Processing Record 24 of the Set 2 | pangoa
# Processing Record 25 of the Set 2 | aklavik
# Processing Record 26 of the Set 2 | mar del plata
# Processing Record 27 of the Set 2 | san cristobal
# Processing Record 28 of the Set 2 | illoqqortoormiut
# Processing Record 29 of the Set 2 | deltona
# Processing Record 30 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of the Set 2 | xapuri
# Processing Record 32 of the Set 2 | cidreira
# Processing Record 33 of the Set 2 | ye
# City not found. Skipping...
# Processing Record 34 of the Set 2 | trincomalee
# Processing Record 35 of the Set 2 | khatanga
# Processing Record 36 of the Set 2 | ponta do sol
# Processing Record 37 of the Set 2 | leningradskiy
# Processing Record 38 of the Set 2 | chuy
# Processing Record 39 of the Set 2 | tasiilaq
# Processing Record 40 of the Set 2 | prainha
# Processing Record 41 of the Set 2 | ponta do sol
# Processing Record 42 of the Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of the Set 2 | flinders
# Processing Record 44 of the Set 2 | alofi
# Processing Record 45 of the Set 2 | pangnirtung
# Processing Record 46 of the Set 2 | quatre cocos
# City not found. Skipping...
# Processing Record 47 of the Set 2 | port elizabeth
# Processing Record 48 of the Set 2 | ocos
# Processing Record 49 of the Set 2 | kuche
# Processing Record 50 of the Set 2 | kenai
# Processing Record 1 of the Set 3 | bengkulu
# Processing Record 2 of the Set 3 | plettenberg bay
# Processing Record 3 of the Set 3 | gizo
# Processing Record 4 of the Set 3 | bluff
# Processing Record 5 of the Set 3 | kemijarvi
# Processing Record 6 of the Set 3 | ponta delgada
# Processing Record 7 of the Set 3 | margate
# Processing Record 8 of the Set 3 | kroya
# Processing Record 9 of the Set 3 | jijiga
# Processing Record 10 of the Set 3 | brae
# Processing Record 11 of the Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of the Set 3 | dikson
# Processing Record 13 of the Set 3 | verkhovyna
# Processing Record 14 of the Set 3 | puerto pinasco
# City not found. Skipping...
# Processing Record 15 of the Set 3 | inta
# Processing Record 16 of the Set 3 | coos bay
# Processing Record 17 of the Set 3 | sur
# Processing Record 18 of the Set 3 | muli
# Processing Record 19 of the Set 3 | georgiyevka
# Processing Record 20 of the Set 3 | mendi
# Processing Record 21 of the Set 3 | oriximina
# Processing Record 22 of the Set 3 | naze
# Processing Record 23 of the Set 3 | warqla
# City not found. Skipping...
# Processing Record 24 of the Set 3 | sovetskiy
# Processing Record 25 of the Set 3 | college
# Processing Record 26 of the Set 3 | oktyabrskiy
# Processing Record 27 of the Set 3 | floriano
# Processing Record 28 of the Set 3 | rocha
# Processing Record 29 of the Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of the Set 3 | new norfolk
# Processing Record 31 of the Set 3 | tuktoyaktuk
# Processing Record 32 of the Set 3 | burpengary
# Processing Record 33 of the Set 3 | ternate
# Processing Record 34 of the Set 3 | faanui
# Processing Record 35 of the Set 3 | ebeltoft
# Processing Record 36 of the Set 3 | kuzino
# Processing Record 37 of the Set 3 | vila velha
# Processing Record 38 of the Set 3 | chimbote
# Processing Record 39 of the Set 3 | sao sebastiao
# Processing Record 40 of the Set 3 | ostrovnoy
# Processing Record 41 of the Set 3 | sinjah
# City not found. Skipping...
# Processing Record 42 of the Set 3 | saint-philippe
# Processing Record 43 of the Set 3 | central point
# Processing Record 44 of the Set 3 | lavrentiya
# Processing Record 45 of the Set 3 | kirensk
# Processing Record 46 of the Set 3 | butaritari
# Processing Record 47 of the Set 3 | kirakira
# Processing Record 48 of the Set 3 | dunedin
# Processing Record 49 of the Set 3 | dauphin
# Processing Record 50 of the Set 3 | hamilton
# Processing Record 1 of the Set 4 | mount gambier
# Processing Record 2 of the Set 4 | high rock
# Processing Record 3 of the Set 4 | faya
# Processing Record 4 of the Set 4 | srostki
# Processing Record 5 of the Set 4 | saskylakh
# Processing Record 6 of the Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of the Set 4 | mahebourg
# City not found. Skipping...
# Processing Record 8 of the Set 4 | rosarito
# Processing Record 9 of the Set 4 | norman wells
# Processing Record 10 of the Set 4 | castro
# Processing Record 11 of the Set 4 | breaza
# Processing Record 12 of the Set 4 | ewo
# Processing Record 13 of the Set 4 | floro
# Processing Record 14 of the Set 4 | dalaba
# Processing Record 15 of the Set 4 | byron bay
# Processing Record 16 of the Set 4 | longyearbyen
# Processing Record 17 of the Set 4 | la grande
# Processing Record 18 of the Set 4 | kalininsk
# Processing Record 19 of the Set 4 | ada
# Processing Record 20 of the Set 4 | jizan
# Processing Record 21 of the Set 4 | vaitape
# Processing Record 22 of the Set 4 | asau
# Processing Record 23 of the Set 4 | sahrak
# City not found. Skipping...
# Processing Record 24 of the Set 4 | san miguel
# Processing Record 25 of the Set 4 | heihe
# Processing Record 26 of the Set 4 | hasaki
# Processing Record 27 of the Set 4 | mehamn
# Processing Record 28 of the Set 4 | aitape
# Processing Record 29 of the Set 4 | talnakh
# Processing Record 30 of the Set 4 | lokoja
# Processing Record 31 of the Set 4 | lodja
# Processing Record 32 of the Set 4 | shimoda
# Processing Record 33 of the Set 4 | namibe
# Processing Record 34 of the Set 4 | uribia
# Processing Record 35 of the Set 4 | xuddur
# Processing Record 36 of the Set 4 | mocajuba
# Processing Record 37 of the Set 4 | bilma
# Processing Record 38 of the Set 4 | haines junction
# Processing Record 39 of the Set 4 | barentsburg
# Processing Record 40 of the Set 4 | portland
# Processing Record 41 of the Set 4 | mamlyutka
# Processing Record 42 of the Set 4 | saint george
# Processing Record 43 of the Set 4 | richards bay
# Processing Record 44 of the Set 4 | tezu
# Processing Record 45 of the Set 4 | ray
# Processing Record 46 of the Set 4 | limbang
# Processing Record 47 of the Set 4 | deputatskiy
# Processing Record 48 of the Set 4 | hinton
# Processing Record 49 of the Set 4 | hofn
# City not found. Skipping...
# Processing Record 50 of the Set 4 | yulara
# Processing Record 1 of the Set 5 | zambrow
# Processing Record 2 of the Set 5 | namanyere
# Processing Record 3 of the Set 5 | kaitangata
# Processing Record 4 of the Set 5 | kindu
# Processing Record 5 of the Set 5 | batagay-alyta
# Processing Record 6 of the Set 5 | east london
# Processing Record 7 of the Set 5 | axim
# Processing Record 8 of the Set 5 | karratha
# Processing Record 9 of the Set 5 | laguna
# Processing Record 10 of the Set 5 | iranshahr
# Processing Record 11 of the Set 5 | wakkanai
# Processing Record 12 of the Set 5 | tessalit
# Processing Record 13 of the Set 5 | hazorasp
# Processing Record 14 of the Set 5 | gat
# Processing Record 15 of the Set 5 | chokurdakh
# Processing Record 16 of the Set 5 | nkhata bay
# Processing Record 17 of the Set 5 | krasnyy yar
# Processing Record 18 of the Set 5 | vallenar
# Processing Record 19 of the Set 5 | kaniama
# Processing Record 20 of the Set 5 | caravelas
# Processing Record 21 of the Set 5 | burica
# City not found. Skipping...
# Processing Record 22 of the Set 5 | bethel
# Processing Record 23 of the Set 5 | sahbuz
# Processing Record 24 of the Set 5 | sambava
# City not found. Skipping...
# Processing Record 25 of the Set 5 | vila franca do campo
# Processing Record 26 of the Set 5 | peniche
# Processing Record 27 of the Set 5 | ormara
# Processing Record 28 of the Set 5 | bambous virieux
# City not found. Skipping...
# Processing Record 29 of the Set 5 | cascais
# Processing Record 30 of the Set 5 | kita
# Processing Record 31 of the Set 5 | edendale
# Processing Record 32 of the Set 5 | darhan
# Processing Record 33 of the Set 5 | avarua
# Processing Record 34 of the Set 5 | macon
# Processing Record 35 of the Set 5 | durgapur
# Processing Record 36 of the Set 5 | narsaq
# Processing Record 37 of the Set 5 | barrow
# Processing Record 38 of the Set 5 | pomabamba
# Processing Record 39 of the Set 5 | trinidad
# Processing Record 40 of the Set 5 | ratanpur
# Processing Record 41 of the Set 5 | barraute
# Processing Record 42 of the Set 5 | liverpool
# Processing Record 43 of the Set 5 | nanortalik
# Processing Record 44 of the Set 5 | malwan
# Processing Record 45 of the Set 5 | luanda
# Processing Record 46 of the Set 5 | puerto escondido
# Processing Record 47 of the Set 5 | hilo
# Processing Record 48 of the Set 5 | pombia
# Processing Record 49 of the Set 5 | lasa
# Processing Record 50 of the Set 5 | vangaindrano
# City not found. Skipping...
# Processing Record 1 of the Set 6 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 2 of the Set 6 | champerico
# Processing Record 3 of the Set 6 | nizhneyansk
# Processing Record 4 of the Set 6 | putnam
# Processing Record 5 of the Set 6 | severo-kurilsk
# Processing Record 6 of the Set 6 | guangyuan
# Processing Record 7 of the Set 6 | hay river
# Processing Record 8 of the Set 6 | ornskoldsvik
# Processing Record 9 of the Set 6 | garowe
# Processing Record 10 of the Set 6 | itoman
# Processing Record 11 of the Set 6 | lucea
# Processing Record 12 of the Set 6 | mys shmidta
# Processing Record 13 of the Set 6 | esperance
# Processing Record 14 of the Set 6 | nola
# Processing Record 15 of the Set 6 | tallahassee
# Processing Record 16 of the Set 6 | khonuu
# Processing Record 17 of the Set 6 | meulaboh
# Processing Record 18 of the Set 6 | qasigiannguit
# Processing Record 19 of the Set 6 | talara
# Processing Record 20 of the Set 6 | geilo
# Processing Record 21 of the Set 6 | antalya
# Processing Record 22 of the Set 6 | airai
# Processing Record 23 of the Set 6 | pathein
# City not found. Skipping...
# Processing Record 24 of the Set 6 | cabo san lucas
# Processing Record 25 of the Set 6 | gasa
# Processing Record 26 of the Set 6 | grand-santi
# Processing Record 27 of the Set 6 | klaksvik
# Processing Record 28 of the Set 6 | san luis
# Processing Record 29 of the Set 6 | geraldton
# Processing Record 30 of the Set 6 | codrington
# Processing Record 31 of the Set 6 | santa cruz
# Processing Record 32 of the Set 6 | kruisfontein
# Processing Record 33 of the Set 6 | rio gallegos
# Processing Record 34 of the Set 6 | nome
# Processing Record 35 of the Set 6 | port macquarie
# Processing Record 36 of the Set 6 | sopot
# Processing Record 37 of the Set 6 | hervey bay
# Processing Record 38 of the Set 6 | bereda
# Processing Record 39 of the Set 6 | beringovskiy
# Processing Record 40 of the Set 6 | lata
# Processing Record 41 of the Set 6 | la sarre
# Processing Record 42 of the Set 6 | morales
# Processing Record 43 of the Set 6 | sri aman
# Processing Record 44 of the Set 6 | qaqortoq
# Processing Record 45 of the Set 6 | port lincoln
# Processing Record 46 of the Set 6 | kavaratti
# Processing Record 47 of the Set 6 | imeni poliny osipenko
# Processing Record 48 of the Set 6 | nuuk
# Processing Record 49 of the Set 6 | ampanihy
# City not found. Skipping...
# Processing Record 50 of the Set 6 | sinop
# Processing Record 1 of the Set 7 | ust-tsilma
# Processing Record 2 of the Set 7 | komsomolskiy
# Processing Record 3 of the Set 7 | goderich
# Processing Record 4 of the Set 7 | bathsheba
# Processing Record 5 of the Set 7 | srednekolymsk
# Processing Record 6 of the Set 7 | sabang
# Processing Record 7 of the Set 7 | tautira
# Processing Record 8 of the Set 7 | petropavlovsk-kamchatskiy
# Processing Record 9 of the Set 7 | maniitsoq
# Processing Record 10 of the Set 7 | saint-chamond
# Processing Record 11 of the Set 7 | necochea
# Processing Record 12 of the Set 7 | irimbo
# Processing Record 13 of the Set 7 | ordubad
# Processing Record 14 of the Set 7 | tahoua
# Processing Record 15 of the Set 7 | longlac
# Processing Record 16 of the Set 7 | ayios matthaios
# Processing Record 17 of the Set 7 | banda aceh
# Processing Record 18 of the Set 7 | iqaluit
# Processing Record 19 of the Set 7 | esqueda
# Processing Record 20 of the Set 7 | kununurra
# Processing Record 21 of the Set 7 | pevek
# Processing Record 22 of the Set 7 | bang racham
# Processing Record 23 of the Set 7 | manggar
# Processing Record 24 of the Set 7 | soe
# Processing Record 25 of the Set 7 | chukhloma
# Processing Record 26 of the Set 7 | grindavik
# City not found. Skipping...
# Processing Record 27 of the Set 7 | port arthur
# Processing Record 28 of the Set 7 | geraldton
# Processing Record 29 of the Set 7 | provideniya
# Processing Record 30 of the Set 7 | snezhnogorsk
# Processing Record 31 of the Set 7 | olafsvik
# City not found. Skipping...
# Processing Record 32 of the Set 7 | grand gaube
# City not found. Skipping...
# Processing Record 33 of the Set 7 | arlit
# Processing Record 34 of the Set 7 | shishou
# Processing Record 35 of the Set 7 | hue
# Processing Record 36 of the Set 7 | sistranda
# Processing Record 37 of the Set 7 | rafaela
# Processing Record 38 of the Set 7 | mogadishu
# Processing Record 39 of the Set 7 | viesca
# Processing Record 40 of the Set 7 | port moresby
# Processing Record 41 of the Set 7 | sao joao da barra
# Processing Record 42 of the Set 7 | ginda
# Processing Record 43 of the Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of the Set 7 | kerman
# Processing Record 45 of the Set 7 | narasannapeta
# Processing Record 46 of the Set 7 | sao paulo de olivenca
# Processing Record 47 of the Set 7 | la carolina
# Processing Record 48 of the Set 7 | aguia branca
# Processing Record 49 of the Set 7 | santa cruz
# Processing Record 50 of the Set 7 | jacqueville
# Processing Record 1 of the Set 8 | poopo
# Processing Record 2 of the Set 8 | sembabule
# Processing Record 3 of the Set 8 | ribeira grande
# Processing Record 4 of the Set 8 | susa
# Processing Record 5 of the Set 8 | fukue
# Processing Record 6 of the Set 8 | sao filipe
# Processing Record 7 of the Set 8 | nsoko
# Processing Record 8 of the Set 8 | varkaus
# Processing Record 9 of the Set 8 | russell
# Processing Record 10 of the Set 8 | kungurtug
# Processing Record 11 of the Set 8 | sulphur
# Processing Record 12 of the Set 8 | mondlo
# Processing Record 13 of the Set 8 | hualmay
# Processing Record 14 of the Set 8 | thompson
# Processing Record 15 of the Set 8 | isabela
# Processing Record 16 of the Set 8 | tirumullaivasal
# Processing Record 17 of the Set 8 | mahadday weyne
# Processing Record 18 of the Set 8 | mahibadhoo
# Processing Record 19 of the Set 8 | nha trang
# Processing Record 20 of the Set 8 | belaya gora
# Processing Record 21 of the Set 8 | adre
# Processing Record 22 of the Set 8 | lidice
# City not found. Skipping...
# Processing Record 23 of the Set 8 | te anau
# Processing Record 24 of the Set 8 | mutsu
# Processing Record 25 of the Set 8 | arkhangelos
# Processing Record 26 of the Set 8 | moses lake
# Processing Record 27 of the Set 8 | kilinochchi
# Processing Record 28 of the Set 8 | bima
# Processing Record 29 of the Set 8 | manokwari
# Processing Record 30 of the Set 8 | musoma
# Processing Record 31 of the Set 8 | birobidzhan
# Processing Record 32 of the Set 8 | trairi
# Processing Record 33 of the Set 8 | cap malheureux
# City not found. Skipping...
# Processing Record 34 of the Set 8 | hit
# Processing Record 35 of the Set 8 | salme
# Processing Record 36 of the Set 8 | dong hoi
# Processing Record 37 of the Set 8 | pisco
# Processing Record 38 of the Set 8 | weihe
# Processing Record 39 of the Set 8 | mackay
# Processing Record 40 of the Set 8 | kukes
# Processing Record 41 of the Set 8 | cairns
# Processing Record 42 of the Set 8 | cabedelo
# Processing Record 43 of the Set 8 | vardo
# Processing Record 44 of the Set 8 | tabialan
# City not found. Skipping...
# Processing Record 45 of the Set 8 | coquimbo
# Processing Record 46 of the Set 8 | cortez
# Processing Record 47 of the Set 8 | lebedinyy
# Processing Record 48 of the Set 8 | hami
# Processing Record 49 of the Set 8 | upington
# Processing Record 50 of the Set 8 | bargal
# Processing Record 1 of the Set 9 | bangui
# Processing Record 2 of the Set 9 | tombouctou
# Processing Record 3 of the Set 9 | nchelenge
# Processing Record 4 of the Set 9 | bowen
# Processing Record 5 of the Set 9 | jeremie
# Processing Record 6 of the Set 9 | cheuskiny
# Processing Record 7 of the Set 9 | palembang
# Processing Record 8 of the Set 9 | henties bay
# Processing Record 9 of the Set 9 | kattivakkam
# Processing Record 10 of the Set 9 | labuhan
# Processing Record 11 of the Set 9 | abonnema
# Processing Record 12 of the Set 9 | oktyabrskoye
# Processing Record 13 of the Set 9 | pavlodar
# Processing Record 14 of the Set 9 | maraa
# Processing Record 15 of the Set 9 | san policarpo
# City not found. Skipping...
# Processing Record 16 of the Set 9 | lorengau
# Processing Record 17 of the Set 9 | conceicao do araguaia
# Processing Record 18 of the Set 9 | nizwa
# Processing Record 19 of the Set 9 | tadine
# Processing Record 20 of the Set 9 | nova olimpia
# Processing Record 21 of the Set 9 | nemuro
# Processing Record 22 of the Set 9 | rawson
# Processing Record 23 of the Set 9 | massakory
# Processing Record 24 of the Set 9 | kirkenes
# Processing Record 25 of the Set 9 | amderma
# Processing Record 26 of the Set 9 | muros
# Processing Record 27 of the Set 9 | kralendijk
# Processing Record 28 of the Set 9 | rawalpindi
# Processing Record 29 of the Set 9 | los llanos de aridane
# Processing Record 30 of the Set 9 | port hardy
# Processing Record 31 of the Set 9 | bacuit
# City not found. Skipping...
# Processing Record 32 of the Set 9 | mulhouse
# Processing Record 33 of the Set 9 | jiuquan
# Processing Record 34 of the Set 9 | mount isa
# Processing Record 35 of the Set 9 | le portel
# Processing Record 36 of the Set 9 | buchanan
# Processing Record 37 of the Set 9 | anori
# Processing Record 38 of the Set 9 | coari
# Processing Record 39 of the Set 9 | kapuskasing
# Processing Record 40 of the Set 9 | madimba
# Processing Record 41 of the Set 9 | opuwo
# Processing Record 42 of the Set 9 | san patricio
# Processing Record 43 of the Set 9 | broken hill
# Processing Record 44 of the Set 9 | paamiut
# Processing Record 45 of the Set 9 | issenye
# Processing Record 46 of the Set 9 | omsukchan
# Processing Record 47 of the Set 9 | roald
# Processing Record 48 of the Set 9 | lebu
# Processing Record 49 of the Set 9 | lazaro cardenas
# Processing Record 50 of the Set 9 | victoria
# Processing Record 1 of the Set 10 | tiksi
# Processing Record 2 of the Set 10 | hobyo
# Processing Record 3 of the Set 10 | alice springs
# Processing Record 4 of the Set 10 | caidian
# Processing Record 5 of the Set 10 | beausejour
# Processing Record 6 of the Set 10 | general pico
# Processing Record 7 of the Set 10 | pithoro
# Processing Record 8 of the Set 10 | hangu
# Processing Record 9 of the Set 10 | khandbari
# Processing Record 10 of the Set 10 | jambi
# Processing Record 11 of the Set 10 | santa fe
# Processing Record 12 of the Set 10 | riyadh
# Processing Record 13 of the Set 10 | waipawa
# Processing Record 14 of the Set 10 | nyurba
# Processing Record 15 of the Set 10 | lompoc
# Processing Record 16 of the Set 10 | contamana
# Processing Record 17 of the Set 10 | songea
# Processing Record 18 of the Set 10 | novikovo
# Processing Record 19 of the Set 10 | okahandja
# Processing Record 20 of the Set 10 | kargasok
# Processing Record 21 of the Set 10 | ajdabiya
# Processing Record 22 of the Set 10 | tabiauea
# Processing Record 23 of the Set 10 | kaabong
# Processing Record 24 of the Set 10 | bilibino
# Processing Record 25 of the Set 10 | general roca
# Processing Record 26 of the Set 10 | honiara
# Processing Record 27 of the Set 10 | liepaja
# Processing Record 28 of the Set 10 | manicore
# Processing Record 29 of the Set 10 | nikologory
# Processing Record 30 of the Set 10 | fairbanks
# Processing Record 31 of the Set 10 | bela
# Processing Record 32 of the Set 10 | atar
# Processing Record 33 of the Set 10 | walvis bay
# Processing Record 34 of the Set 10 | tahta
# Processing Record 35 of the Set 10 | amahai
# Processing Record 36 of the Set 10 | moussoro
# Processing Record 37 of the Set 10 | sterlibashevo
# Processing Record 38 of the Set 10 | ambon
# Processing Record 39 of the Set 10 | erdenet
# Processing Record 40 of the Set 10 | mapimi
# Processing Record 41 of the Set 10 | touros
# Processing Record 42 of the Set 10 | acapulco
# Processing Record 43 of the Set 10 | morada nova
# Processing Record 44 of the Set 10 | aykhal
# Processing Record 45 of the Set 10 | buin
# Processing Record 46 of the Set 10 | jaguarao
# Processing Record 47 of the Set 10 | jirkov
# Processing Record 48 of the Set 10 | koungou
# Processing Record 49 of the Set 10 | senanga
# Processing Record 50 of the Set 10 | santa marta
# Processing Record 1 of the Set 11 | shelabolikha
# Processing Record 2 of the Set 11 | uyuni
# Processing Record 3 of the Set 11 | mandera
# Processing Record 4 of the Set 11 | viedma
# Processing Record 5 of the Set 11 | olinda
# Processing Record 6 of the Set 11 | oga
# Processing Record 7 of the Set 11 | anito
# City not found. Skipping...
# Processing Record 8 of the Set 11 | palmer
# Processing Record 9 of the Set 11 | mayo
# Processing Record 10 of the Set 11 | bahar
# Processing Record 11 of the Set 11 | mineiros
# Processing Record 12 of the Set 11 | daoukro
# Processing Record 13 of the Set 11 | nurota
# Processing Record 14 of the Set 11 | anderson
# Processing Record 15 of the Set 11 | wainwright
# Processing Record 16 of the Set 11 | puerto del rosario
# Processing Record 17 of the Set 11 | inhambane
# Processing Record 18 of the Set 11 | lolua
# Processing Record 19 of the Set 11 | halifax
# Processing Record 20 of the Set 11 | vasai
# Processing Record 21 of the Set 11 | lovozero
# Processing Record 22 of the Set 11 | brignoles
# Processing Record 23 of the Set 11 | marcona
# Processing Record 24 of the Set 11 | beliator
# Processing Record 25 of the Set 11 | luwuk
# Processing Record 26 of the Set 11 | yarmouth
# Processing Record 27 of the Set 11 | samba
# Processing Record 28 of the Set 11 | dakar
# Processing Record 29 of the Set 11 | ler
# City not found. Skipping...
# Processing Record 30 of the Set 11 | katsuura
# Processing Record 31 of the Set 11 | souillac
# City not found. Skipping...
# Processing Record 32 of the Set 11 | santa rosa
# Processing Record 33 of the Set 11 | celestun
# Processing Record 34 of the Set 11 | solotcha
# Processing Record 35 of the Set 11 | pokhara
# Processing Record 36 of the Set 11 | guaratuba
# Processing Record 37 of the Set 11 | seryshevo
# Processing Record 38 of the Set 11 | shingu
# Processing Record 39 of the Set 11 | kahului
# Processing Record 40 of the Set 11 | gigmoto
# City not found. Skipping...
# Processing Record 41 of the Set 11 | moindou
# Processing Record 42 of the Set 11 | yen bai
# Processing Record 43 of the Set 11 | uige
# Processing Record 44 of the Set 11 | svetlaya
# Processing Record 45 of the Set 11 | surgana
# Processing Record 46 of the Set 11 | warrington
# Processing Record 47 of the Set 11 | odweyne
# Processing Record 48 of the Set 11 | igarka
# Processing Record 49 of the Set 11 | araouane
# Processing Record 50 of the Set 11 | trelew
# Processing Record 1 of the Set 12 | marawi
# City not found. Skipping...
# Processing Record 2 of the Set 12 | forestville
# Processing Record 3 of the Set 12 | fuerte olimpo
# City not found. Skipping...
# Processing Record 4 of the Set 12 | la asuncion
# Processing Record 5 of the Set 12 | kushmurun
# Processing Record 6 of the Set 12 | koygorodok
# Processing Record 7 of the Set 12 | isangel
# Processing Record 8 of the Set 12 | tidore
# Processing Record 9 of the Set 12 | simbakoro
# Processing Record 10 of the Set 12 | saint-francois
# Processing Record 11 of the Set 12 | sukumo
# Processing Record 12 of the Set 12 | smidovich
# Processing Record 13 of the Set 12 | ismailia
# Processing Record 14 of the Set 12 | belyy yar
# Processing Record 15 of the Set 12 | warmbad
# Processing Record 16 of the Set 12 | gornyak
# Processing Record 17 of the Set 12 | adrar
# City not found. Skipping...
# Processing Record 18 of the Set 12 | quesnel
# Processing Record 19 of the Set 12 | yarada
# Processing Record 20 of the Set 12 | saurimo
# Processing Record 21 of the Set 12 | constitucion
# Processing Record 22 of the Set 12 | mbaiki
# Processing Record 23 of the Set 12 | porto-vecchio
# Processing Record 24 of the Set 12 | grand forks
# Processing Record 25 of the Set 12 | nuoro
# Processing Record 26 of the Set 12 | dunmore town
# Processing Record 27 of the Set 12 | takoradi
# Processing Record 28 of the Set 12 | ballina
# Processing Record 29 of the Set 12 | ust-nera
# Processing Record 30 of the Set 12 | palamos
# Processing Record 31 of the Set 12 | stornoway
# Processing Record 32 of the Set 12 | hauterive
# Processing Record 33 of the Set 12 | bone
# Processing Record 34 of the Set 12 | tabuk
# Processing Record 35 of the Set 12 | liancheng
# Processing Record 36 of the Set 12 | guaruja
# Processing Record 37 of the Set 12 | pyapon
# City not found. Skipping...
# Processing Record 38 of the Set 12 | edeia
# Processing Record 39 of the Set 12 | hambantota
# Processing Record 40 of the Set 12 | santa isabel do rio negro
# Processing Record 41 of the Set 12 | saint-augustin
# Processing Record 42 of the Set 12 | matagami
# Processing Record 43 of the Set 12 | pacific grove
# Processing Record 44 of the Set 12 | tres arroyos
# Processing Record 45 of the Set 12 | halalo
# City not found. Skipping...
# Processing Record 46 of the Set 12 | mormugao
# Processing Record 47 of the Set 12 | agadez
# Processing Record 48 of the Set 12 | arcata
# Processing Record 49 of the Set 12 | monmouth
# Processing Record 50 of the Set 12 | taoudenni
# Processing Record 1 of the Set 13 | phalodi
# Processing Record 2 of the Set 13 | miri
# Processing Record 3 of the Set 13 | guerrero negro
# Processing Record 4 of the Set 13 | havre-saint-pierre
# Processing Record 5 of the Set 13 | bandarbeyla
# Processing Record 6 of the Set 13 | mwene-ditu
# Processing Record 7 of the Set 13 | melilla
# Processing Record 8 of the Set 13 | lixourion
# Processing Record 9 of the Set 13 | kailua
# Processing Record 10 of the Set 13 | weihai
# Processing Record 11 of the Set 13 | progreso
# Processing Record 12 of the Set 13 | sisimiut
# Processing Record 13 of the Set 13 | tamiahua
# Processing Record 14 of the Set 13 | okhotsk
# Processing Record 15 of the Set 13 | rivadavia
# Processing Record 16 of the Set 13 | shibetsu
# Processing Record 17 of the Set 13 | santa barbara
# Processing Record 18 of the Set 13 | roebourne
# Processing Record 19 of the Set 13 | lom sak
# Processing Record 20 of the Set 13 | sinnamary
# Processing Record 21 of the Set 13 | valleyview
# Processing Record 22 of the Set 13 | along
# Processing Record 23 of the Set 13 | alekseyevsk
# Processing Record 24 of the Set 13 | seaford
# Processing Record 25 of the Set 13 | ulvik
# Processing Record 26 of the Set 13 | samarai
# Processing Record 27 of the Set 13 | domoni
# Processing Record 28 of the Set 13 | sao felix do xingu
# Processing Record 29 of the Set 13 | bonavista
# Processing Record 30 of the Set 13 | sakhipur
# Processing Record 31 of the Set 13 | rabo de peixe
# Processing Record 32 of the Set 13 | correntina
# Processing Record 33 of the Set 13 | chai badan
# Processing Record 34 of the Set 13 | canon city
# Processing Record 35 of the Set 13 | umzimvubu
# Processing Record 36 of the Set 13 | belfast
# Processing Record 37 of the Set 13 | annecy
# Processing Record 38 of the Set 13 | kuusamo
# Processing Record 39 of the Set 13 | dehui
# Processing Record 40 of the Set 13 | zarate
# Processing Record 41 of the Set 13 | grand centre
# Processing Record 42 of the Set 13 | muravlenko
# Processing Record 43 of the Set 13 | simga
# Processing Record 44 of the Set 13 | awjilah
# Processing Record 45 of the Set 13 | superior
# Processing Record 46 of the Set 13 | buala
# Processing Record 47 of the Set 13 | ixtapa
# Processing Record 48 of the Set 13 | mathbaria
# Processing Record 49 of the Set 13 | japura
# Processing Record 50 of the Set 13 | auch
# Processing Record 1 of the Set 14 | urengoy
# Processing Record 2 of the Set 14 | husavik
# City not found. Skipping...
# Processing Record 3 of the Set 14 | teya
# Processing Record 4 of the Set 14 | bafra
# Processing Record 5 of the Set 14 | pilar
# City not found. Skipping...
# Processing Record 6 of the Set 14 | bur gabo
# Processing Record 7 of the Set 14 | mobaye
# Processing Record 8 of the Set 14 | sitka
# Processing Record 9 of the Set 14 | chuzhou
# Processing Record 10 of the Set 14 | mumford
# Processing Record 11 of the Set 14 | kalmunai
# Processing Record 12 of the Set 14 | mergui
# City not found. Skipping...
# Processing Record 13 of the Set 14 | aksu
# Processing Record 14 of the Set 14 | kaeo
# Processing Record 15 of the Set 14 | macia
# Processing Record 16 of the Set 14 | maceio
# Processing Record 17 of the Set 14 | bougouni
# Processing Record 18 of the Set 14 | conde
# Processing Record 19 of the Set 14 | north bend
# Processing Record 20 of the Set 14 | chicama
# Processing Record 21 of the Set 14 | kautokeino
# Processing Record 22 of the Set 14 | karaton
# Processing Record 23 of the Set 14 | belmonte
# Processing Record 24 of the Set 14 | falealupo
# City not found. Skipping...
# Processing Record 25 of the Set 14 | la baneza
# Processing Record 26 of the Set 14 | avera
# Processing Record 27 of the Set 14 | abu samrah
# Processing Record 28 of the Set 14 | najran
# Processing Record 29 of the Set 14 | vitim
# Processing Record 30 of the Set 14 | san luis
# Processing Record 31 of the Set 14 | synya
# Processing Record 32 of the Set 14 | sioux lookout
# Processing Record 33 of the Set 14 | lebyazhye
# Processing Record 34 of the Set 14 | tuatapere
# Processing Record 35 of the Set 14 | itarema
# Processing Record 36 of the Set 14 | lubango
# Processing Record 37 of the Set 14 | port blair
# Processing Record 38 of the Set 14 | gamba
# Processing Record 39 of the Set 14 | mastic beach
# Processing Record 40 of the Set 14 | prince rupert
# Processing Record 41 of the Set 14 | eureka
# Processing Record 42 of the Set 14 | camana
# Processing Record 43 of the Set 14 | poum
# Processing Record 44 of the Set 14 | chinhoyi
# Processing Record 45 of the Set 14 | mataquescuintla
# Processing Record 46 of the Set 14 | hermitage
# Processing Record 47 of the Set 14 | fevralsk
# Processing Record 48 of the Set 14 | zhangye
# Processing Record 49 of the Set 14 | shitanjing
# Processing Record 50 of the Set 14 | san rafael
# Processing Record 1 of the Set 15 | somerset east
# Processing Record 2 of the Set 15 | san felipe
# Processing Record 3 of the Set 15 | tubruq
# Processing Record 4 of the Set 15 | camabatela
# Processing Record 5 of the Set 15 | mwinilunga
# Processing Record 6 of the Set 15 | juba
# City not found. Skipping...
# Processing Record 7 of the Set 15 | loreto
# Processing Record 8 of the Set 15 | ayios stefanos
# Processing Record 9 of the Set 15 | san
# Processing Record 10 of the Set 15 | oranjestad
# Processing Record 11 of the Set 15 | luba
# Processing Record 12 of the Set 15 | pundaguitan
# City not found. Skipping...
# Processing Record 13 of the Set 15 | yar-sale
# Processing Record 14 of the Set 15 | porto novo
# Processing Record 15 of the Set 15 | westport
# Processing Record 16 of the Set 15 | marquette
# Processing Record 17 of the Set 15 | toliary
# City not found. Skipping...
# Processing Record 18 of the Set 15 | rungata
# Processing Record 19 of the Set 15 | seoul
# Processing Record 20 of the Set 15 | jonuta
# Processing Record 21 of the Set 15 | grootfontein
# Processing Record 22 of the Set 15 | goure
# Processing Record 23 of the Set 15 | vanimo
# Processing Record 24 of the Set 15 | nishihara
# Processing Record 25 of the Set 15 | palaikastron
# Processing Record 26 of the Set 15 | moron
# Processing Record 27 of the Set 15 | maryborough
# Processing Record 28 of the Set 15 | we
# Processing Record 29 of the Set 15 | zhigansk
# Processing Record 30 of the Set 15 | neuquen
# Processing Record 31 of the Set 15 | nalut
# Processing Record 32 of the Set 15 | saleaula
# City not found. Skipping...
# Processing Record 33 of the Set 15 | trofarello
# Processing Record 34 of the Set 15 | gracac
# Processing Record 35 of the Set 15 | mangrol
# Processing Record 36 of the Set 15 | blackfoot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 690

# %%
# Step 4 - Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vaini      TO -21.2000 -175.2000     77.00        94          40
# 1  Coihaique      CL -45.5752  -72.0662     59.00        51          75
# 2     Albany      US  42.6001  -73.9662     26.01        61         100
# 3    Rikitea      PF -23.1203 -134.9692     77.68        77         100
# 4      Kapaa      US  22.0752 -159.3190     64.40        94           1
#
#    Wind Speed Current Description
# 0        3.44    scattered clouds
# 1        6.91       moderate rain
# 2        3.00     overcast clouds
# 3       12.39     overcast clouds
# 4        8.05           clear sky

# %%
# Step 5 - Export the DataFrame as a CSV file "WeatherPy_Database.csv"
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
